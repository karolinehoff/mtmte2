# %%
from collections import Counter
from IPython.display import FileLink
import pandas as pd
import numpy as np

# %%
def parse(filename, cols):
    # Returns a list of queries

    df = pd.read_csv(filename, sep=',', encoding='utf-8',
                     usecols=cols.keys(), dtype=cols, keep_default_na=False)

    query_col = 'search string cleaned'
    queries = []
    n = 0
    for idx, row in df.iterrows():
        n += 1
        for _ in range(row['searches']):
            queries.append(row[query_col])
    print('%s: Read %d rows' % (filename, n))
    return queries

# %%
def print_stats(qr):
    qd = set(qr)

    nchars_qr = np.array([len(x) for x in qr])
    nchars_qd = np.array([len(x) for x in qd])

    nwords_qr = np.array([len(x.split()) for x in qr])
    nwords_qd = np.array([len(x.split()) for x in qd])

    print('- Number of queries: %d' % len(qr))
    print('  - mean number of words: %.2f' % np.mean(nwords_qr))
    print('  - median number of words: %.2f' % np.median(nwords_qr))
    print('  - mean number of chars: %.2f' % np.mean(nchars_qr))
    print('  - median number of chars: %.2f' % np.median(nchars_qr))

    print('- number of distinct queries: %d' % len(qd))
    print('  - mean number of words: %.2f' % np.mean(nwords_qd))
    print('  - median number of words: %.2f' % np.median(nwords_qd))
    print('  - mean number of chars: %.2f' % np.mean(nchars_qd))
    print('  - median number of chars: %.2f' % np.median(nchars_qd))

# %%
# Zero result queries: Stats for the complete set
qr = parse('zero-23-24.csv', {
        'searches': np.int32,
        'search string cleaned': np.str_,
    })
            
print_stats(qr)
print()


# Zero result queries: Stats the dataset limited to match MTMTE1
qr = parse('zero-23-24-mtmte1.csv', {
        'searches': np.int32,
        'search string cleaned': np.str_,
    })
            
print_stats(qr)
print()
# Out:
# Whole dataset
# zero-23-24.csv: Read 70149 rows
# - Number of queries: 91057
#   - mean number of words: 7.18
#   - median number of words: 5.00
#   - mean number of chars: 51.92
#   - median number of chars: 37.00
# - number of distinct queries: 65529
#   - mean number of words: 7.28
#   - median number of words: 5.00
#   - mean number of chars: 52.31
#   - median number of chars: 37.00
#
# Selected range
# zero-23-24-mtmte1.csv: Read 41042 rows
# - Number of queries: 53496
#   - mean number of words: 7.16
#   - median number of words: 5.00
#   - mean number of chars: 51.81
#   - median number of chars: 37.00
# - number of distinct queries: 38396
#   - mean number of words: 7.28
#   - median number of words: 5.00
#   - mean number of chars: 52.35
#   - median number of chars: 37.00

# %%
#Lage tilfeldig uttrekk for analyse

def parse_and_sample(filename, cols, sample_size, random_seed):
    # Read the CSV file
    df = pd.read_csv(filename, sep=',', encoding='utf-8',
                     usecols=cols.keys(), dtype=cols, keep_default_na=False)
    
    # Randomly sample 50 rows from the filtered data
    sampled_df = df.sample(n=sample_size, random_state=random_seed)
    
    # Ensure the specified columns are included
    specified_columns = ['date', 'searches', 'search string', 'search string cleaned', 
                         'field searched', 'search type', 'active tab', 'resource type pre-filter', 
                         'signed in', 'on campus']
    
    # Filter the DataFrame to include only the specified columns
    sampled_df = sampled_df[specified_columns]
    
    # Export the sampled rows to a new CSV file
    sampled_df.to_csv('zero-23-24-sample.csv', index=False)
    
    # Print the results
    print(sampled_df)
    
    # Create download link
    from IPython.display import FileLink
    display(FileLink('zero-23-24-sample.csv'))

# %%
#Kjører uttrekk
cols = {'year': int, 'month': int, 'date': str, 'search string': str, 'search string cleaned': str, 
        'field searched': str, 'search type': str, 'active tab': str, 'resource type pre-filter': str, 
        'signed in': str, 'on campus': str, 'searches': int}

#Filnavn, kolonnene over, antall rader, nummer på random seed
parse_and_sample('zero-23-24.csv', cols, 50, random_seed=4)
# Out:
#              date  searches  \
# 10985  2023-04-25         1
# 67043  2024-11-28         1
# 3732   2023-02-08         2
# 11869  2023-05-04         2
# 50392  2024-06-08         1
# 2606   2023-01-28         1
# 69832  2024-12-28         3
# 68249  2024-12-11         1
# 20117  2023-07-29         1
# 395    2023-01-05         2
# 33611  2023-12-17         1
# 52052  2024-06-25         1
# 25167  2023-09-21         1
# 19913  2023-07-27         1
# 8605   2023-03-31         2
# 12268  2023-05-08         1
# 27426  2023-10-14         1
# 50292  2024-06-07         1
# 44818  2024-04-12         1
# 41561  2024-03-09         1
# 25748  2023-09-27         1
# 68282  2024-12-11         1
# 19901  2023-07-27         1
# 51964  2024-06-24         1
# 27951  2023-10-19         1
# 37180  2024-01-24         1
# 8446   2023-03-30         2
# 22027  2023-08-19         1
# 15646  2023-06-13         2
# 22184  2023-08-21         2
# 40087  2024-02-23         1
# 2228   2023-01-24         1
# 49643  2024-06-01         1
# 35284  2024-01-04         2
# 47714  2024-05-12         1
# 21681  2023-08-16         4
# 10217  2023-04-17         2
# 14240  2023-05-29         4
# 32373  2023-12-04         2
# 13119  2023-05-17         1
# 30987  2023-11-20         1
# 33691  2023-12-18         1
# 30906  2023-11-19         1
# 36672  2024-01-19         1
# 45988  2024-04-24         1
# 21919  2023-08-18         1
# 15195  2023-06-08         2
# 7763   2023-03-23         1
# 31792  2023-11-28         1
# 53708  2024-07-13         2
#
#                                            search string  \
# 10985            10.7551/mitpress/9780262028431.001.0001
# 67043  Community Development and Persistence in a Low...
# 3732                Cinema as Representational Art abell
# 11869                Bowman, C. P. (2017). Masturbation.
# 50392                                 dagsordenhypotesen
# 2606   Barnevernet og barneloven,Barnevernet og barne...
# 69832                               joe dumit how i read
# 68249  A Meta-Analysis of After-School Programs That ...
# 20117                 Weaver  W. 1949/1955. Translation.
# 395    "Students' Transition from Extended to Mainstr...
# 33611  Mercer, N. %26 Littleton, K. (2007): Dialogue ...
# 52052                                 Laura Watts,Orkney
# 25167  "Some Reflections on the Nature of Knowledge i...
# 19913  The value sphere: the corporate executives' ha...
# 8605        Bookchin Spocial ecology versus deep ecology
# 12268  Byrne, Patrick. “Chapter 4 The Structure of Et...
# 27426  Kari Stefansen, Ingrid Holtan, and Thomas Joha...
# 50292  Kalwij, A., %26 Vermeulen, F. Health and labou...
# 44818  1 Russko-norve?skij slovar' V.P. Berkov ; pod ...
# 41561  Point of Care Ultrasound (POCUS) Market Size -...
# 25748                               "hva er et prinsipp"
# 68282  Entangled Geographies: Empire and Technopoliti...
# 19901                           Pottetreningpå tre dager
# 51964  L'Eutidemo di Platone: Una Commedia Straordina...
# 27951  Fielding S. The Executioner’s Bible: The Story...
# 37180                                       Arnhild skre
# 8446   (Kumar (Morality and Life skills The need and ...
# 22027  The construction of hierarchy: rethinking the ...
# 15646                      "klosterneuburg annunciation"
# 22184                                 10.1037/t11524-000
# 40087  Carr-Fanning, K. %26 Curran, H. (2023) The spe...
# 2228                                       9783035804812
# 49643  "Gendered Dimensions of the Returnee Experienc...
# 35284                   Hovedgårder, stormenn og landnåm
# 47714           "kompetanse" "lærer" "utagerende atferd"
# 21681  "Thor medical"Thor Medicals FORSKNINGSPRODUKSJ...
# 10217                                   Aftersun zornosa
# 14240                           DOI: 10.1055/a-2100-2258
# 32373  Custody contest: How to divide and reassemble ...
# 13119  Wolfgang J. A. Bender Ingenium animum humanum ...
# 30987                A24’s Aesthetics of Counter Culture
# 33691                                      9788761944351
# 30906  N.E.Adler,W.T.Boyce,M.A.Chesney,S.Folkman,S.L.Sym
# 36672                                         8214026067
# 45988         Allan Turner Style and Intertextual Echoes
# 21919  Geophagia History, Epidemiology, and Etiology ...
# 15195                                      9781788212823
# 7763                       "bekreftende forutinntatthet"
# 31792  Bhavnani, K.-K. (2014). Performing diaspora: C...
# 53708  "Norwegian women’s motivations and preparation...
#
#                                    search string cleaned   field searched  \
# 10985                 107551mitpress97802620284310010001              any
# 67043  community development and persistence in a low...              any
# 3732                cinema as representational art abell              any
# 11869                       bowman c p 2017 masturbation              any
# 50392                                 dagsordenhypotesen              any
# 2606   barnevernet og barnelovenbarnevernet og barnel...  any,any,any,any
# 69832                               joe dumit how i read              any
# 68249  a metaanalysis of afterschool programs that se...              any
# 20117                      weaver w 19491955 translation              any
# 395    students transition from extended to mainstrea...              any
# 33611  mercer n 26 littleton k 2007 dialogue and the ...              any
# 52052                                  laura wattsorkney    creator,title
# 25167  some reflections on the nature of knowledge in...              any
# 19913  the value sphere the corporate executives hand...              any
# 8605        bookchin spocial ecology versus deep ecology              any
# 12268  byrne patrick chapter 4 the structure of ethic...              any
# 27426  kari stefansen ingrid holtan and thomas johansson              any
# 50292  kalwij a 26 vermeulen f health and labour forc...              any
# 44818  1 russkonorveskij slovar vp berkov pod redakci...              any
# 41561  point of care ultrasound pocus market size by ...              any
# 25748                                 hva er et prinsipp              any
# 68282  entangled geographies empire and technopolitic...              any
# 19901                           pottetreningpå tre dager              any
# 51964  leutidemo di platone una commedia straordinari...              any
# 27951  fielding s the executioners bible the story of...              any
# 37180                                       arnhild skre              any
# 8446   kumar morality and life skills the need and im...              any
# 22027  the construction of hierarchy rethinking the c...              any
# 15646                        klosterneuburg annunciation              any
# 22184                                    101037t11524000              any
# 40087  carrfanning k 26 curran h 2023 the special and...              any
# 2228                                       9783035804812              any
# 49643  gendered dimensions of the returnee experience...              any
# 35284                    hovedgårder stormenn og landnåm              any
# 47714                 kompetanse lærer utagerende atferd              any
# 21681  thor medicalthor medicals forskningsproduksjon...              any
# 10217                                   aftersun zornosa              any
# 14240                                doi 101055a21002258              any
# 32373  custody contest how to divide and reassemble a...              any
# 13119  wolfgang j a bender ingenium animum humanum iuvat              any
# 30987                 a24s aesthetics of counter culture              any
# 33691                                      9788761944351              any
# 30906               neadlerwtboycemachesneysfolkmanslsym              any
# 36672                                         8214026067             isbn
# 45988         allan turner style and intertextual echoes              any
# 21919  geophagia history epidemiology and etiology by...              any
# 15195                                      9781788212823              any
# 7763                         bekreftende forutinntatthet              any
# 31792  bhavnani kk 2014 performing diaspora critical ...              any
# 53708  norwegian womens motivations and preparations ...              any
#
#                            search type   active tab resource type pre-filter  \
# 10985                          Keyword  default_tab                All items
# 67043                          Keyword  default_tab                    Books
# 3732                           Keyword  default_tab                All items
# 11869                          Keyword  default_tab                All items
# 50392                          Keyword  default_tab                All items
# 2606   Keyword,Keyword,Keyword,Keyword  default_tab                All items
# 69832                          Keyword  default_tab                    Books
# 68249                          Keyword  default_tab                All items
# 20117                          Keyword  default_tab                All items
# 395                            Keyword  default_tab                All items
# 33611                          Keyword  default_tab                All items
# 52052                  Keyword,Keyword  default_tab                All items
# 25167                          Keyword  default_tab                All items
# 19913                          Keyword  default_tab                All items
# 8605                           Keyword  default_tab                All items
# 12268                          Keyword  default_tab                All items
# 27426                          Keyword  default_tab                All items
# 50292                          Keyword  default_tab                    Books
# 44818                          Keyword  default_tab                All items
# 41561                          Keyword  default_tab                All items
# 25748                          Keyword  default_tab                All items
# 68282                          Keyword  default_tab                    Books
# 19901                          Keyword  default_tab                All items
# 51964                          Keyword  default_tab                All items
# 27951                          Keyword  default_tab                All items
# 37180                          Keyword  default_tab                All items
# 8446                           Keyword  default_tab                All items
# 22027                          Keyword  default_tab                All items
# 15646                          Keyword  default_tab                All items
# 22184                          Keyword  default_tab                All items
# 40087                          Keyword  default_tab                All items
# 2228                           Keyword  default_tab                All items
# 49643                          Keyword  default_tab                All items
# 35284                          Keyword  default_tab                All items
# 47714                          Keyword  default_tab                 Articles
# 21681                          Keyword  default_tab                All items
# 10217                          Keyword  default_tab                All items
# 14240                          Keyword  default_tab                All items
# 32373                          Keyword  default_tab                All items
# 13119                          Keyword  default_tab                All items
# 30987                          Keyword  default_tab                All items
# 33691                          Keyword  default_tab                All items
# 30906                          Keyword  default_tab                All items
# 36672                          Keyword  default_tab                All items
# 45988                          Keyword  default_tab                All items
# 21919                          Keyword  default_tab                All items
# 15195                          Keyword  default_tab                All items
# 7763                           Keyword  default_tab                All items
# 31792                          Keyword  default_tab                All items
# 53708                          Keyword  default_tab                 Articles
#
#       signed in on campus
# 10985         0         1
# 67043         0         1
# 3732          0         0
# 11869         0         0
# 50392         0         0
# 2606          0         1
# 69832         3         0
# 68249         0         1
# 20117         0         1
# 395           0         0
# 33611         0         0
# 52052         0         1
# 25167         0         1
# 19913         1         1
# 8605          0         2
# 12268         0         0
# 27426         0         0
# 50292         0         1
# 44818         1         0
# 41561         0         0
# 25748         0         0
# 68282         0         0
# 19901         0         0
# 51964         1         0
# 27951         0         0
# 37180         1         0
# 8446          0         2
# 22027         1         1
# 15646         0         0
# 22184         2         0
# 40087         0         0
# 2228          1         1
# 49643         1         0
# 35284         0         0
# 47714         0         0
# 21681         0         0
# 10217         2         0
# 14240         0         0
# 32373         0         0
# 13119         0         0
# 30987         0         0
# 33691         0         0
# 30906         0         0
# 36672         0         1
# 45988         1         0
# 21919         1         1
# 15195         2         0
# 7763          1         0
# 31792         1         0
# 53708         2         0
# zero-23-24-sample.csv
